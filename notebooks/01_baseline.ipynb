# %% [markdown]
# # 01 - Baseline Orbital Data Centre
# 100 MW, silicon, water cooling at 40 C, traditional panel radiator. Establishes the reference radiator area and mass.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.dpi': 110, 'font.size': 11})
from models.baseline_model.run import run
res = run()
pd.Series(res)
# Out:
# coolant_temperature_C              40.000000
# radiator_area_m2               107877.203655
# radiator_mass_kg               755140.425586
# radiator_mass_tonnes              755.140426
# power_density_w_per_m2            926.979905
# specific_rejection_w_per_kg       132.425701
# radiative_efficiency                0.850000
# fin_efficiency                      0.938435
# effective_efficiency                0.797670
# dtype: float64

# %%
labels = ['area_m2','mass_kg']
print(f"Radiator area : {res['radiator_area_m2']:.0f} m^2")
print(f"Radiator mass : {res['radiator_mass_tonnes']:.1f} t")
print(f"Power density : {res['power_density_w_per_m2']:.0f} W/m^2")
# Out:
# Radiator area : 107877 m^2
# Radiator mass : 755.1 t
# Power density : 927 W/m^2
